# %% [markdown]
# #### ONTO and ONE-TO-ONE
#
# - 전사(ONTO) : 공역 = 치역, 치역은 공역의 부분집합이므로 같은 때가 가징 커짐
#
# - 정의 :
#
#      - 정의역 수 > 공역 수
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# - ONE T0 ONE(선형 독립과 같다); 일대일 함수
#
# ![image-3.png](attachment:image-3.png)
#
# - ONE TO ONE이냐 아니야의 의미는 선형 독립이냐 종속이냐 의미다!! 왜?
#
# ![image-4.png](attachment:image-4.png)
#
#
# https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=sw4r&logNo=221949338397

# %% [markdown]
# #### Neural Network Example
#
# - Fully connected layers
#
#  - 선형변환 (과체중 예시)
#
# ![image.png](attachment:image.png)
#
#
# - 동일한 값을 낼 수 밖에 없다(ONE TO ONE)
#
#   - 여러 개가 하나로 mapping한다
#
#   - 유효 정보만 남긴다
#
# ![image-3.png](attachment:image-3.png)
#
#
# - ONTO
#
# - 필요한 부분만 매핑하여 전사한다.
#
# ![image-4.png](attachment:image-4.png)
#
#
# - ONE and ONE T0 ONE
#
# ![image-5.png](attachment:image-5.png)
