# %% [markdown]
# ### 복습
# #### 자료구조
# 데이터를 효과적으로 관리하려고
#
# #### 반복문
# 반복하려고
# 귀찮아서
# 내가 힘드니까
# 쓰라고 하니까
#
# #### 함수
# 정리하려고
# 다음에 다시 쓰려고
# 남한테 주려고

# %% [markdown]
# # 파이썬 클래스
# 최대한(?) 간단히 클래스를 설명해보겠습니다. 기본적인 내용만 설명하기 때문에 파이썬 입문서를 한 권 추가로 읽어 보실 것을 추천드립니다.

# %% [markdown]
# ## 클래스란?

# %% [markdown]
# 클래스는 함수와 같은 의도로 코드를 정리하기 위해 사용합니다. 함수 보다 한 발 더 나아가 관련된 함수와 변수를 하나로 묶어서 정리할 수 있습니다. 관련 있는 통계학/경제학/정치학을 사회과학이라는 보다 큰 카테고리로 묶는 것과 같습니다.
# <img src="https://i.ibb.co/2MgSYz7/class-0.png" width="600" style="float:left" />

# %% [markdown]
# `클래스말고 함수안에 함수를 넣어서 카테고리화 하는것은 불가능 한가요?`

# %%
def f(  ):
    def g(  ):
        return 3
    return g()

# %% [markdown]
# LEGB

# %% [markdown]
# 클래스는 `class` 키워드로 정의(정리) 할 수 있습니다. 함수와 같은 원리로 정의 자체는 아무런 동작을 수행하지 않습니다. 클래스내에 정의된 함수를 특별히 <b>메서드(method)</b>라고 부릅니다. 이 때 함수의 첫 번째 파라미터로 `self`를 추가해야 합니다.

# %%
def 통계학 ():
    print("통계학")

def 경제학 ():
    print("경제학")

def 정치학 ():
    print("정치학")

# %%
class 사회과학:
    def 통계학 (self):
        print("통계학")

    def 경제학 (self):
        print("경제학")

    def 정치학 (self):
        print("정치학")

# %% [markdown]
# 정의된 클래스는 이를 호출해서 생성할 수 있습니다. 클래스로 정의하면 사용하는 방법이 조금 달라지는것 뿐입니다.

# %%
변수 = 사회과학()
print(type(변수))
# Out:
# <class '__main__.사회과학'>

# %% [markdown]
# 클래스를 생성한 결과를 인스턴스/오브젝트/객체 라고 부릅니다. 위 코드는 사회과학 클래스를 생성해서 반환된 사회과학 객체를 변수에 바인딩하는 겁니다. 붕어빵처럼 얼마든지 여러개의 객체를 찍어낼 수 있습니다.

# %%
변수1 = 사회과학()
변수2 = 사회과학()

# %% [markdown]
# 메모리에는 다음과 같이 클래스와 객체가 저장됩니다. 우선 설계도인 "사회과학 클래스"가 메모리에 저장됩니다. 그리고 `변수1 = 사회과학()` 코드가 실행되면 클래스를 복사해서 객체를 메모리의 새로운 공간에 복사하고 이를 변수 1이 가리킵니다. `변수2 = 사회과학()` 코드가 실행되면 동일한 과정이 반복됩니다. 여기서 중요한 점은 <b> 별도의 메모리에 두 객체가 저장</b>된다는 것입니다.

# %% [markdown]
# <img src="https://i.ibb.co/HDPzP9D/class-1.png" width="400" style="float:left" />

# %% [markdown]
# 클래스에 정의된 메서드 (함수)는 객체를 통해 호출할 수 있습니다. 위 그림을 참고하면 변수1 객체에는 사회과학 클래스로부터 복사된 세 개의 함수가 정의돼 있습니다. 이를 호출하는 코드는 다음과 같습니다.

# %%
class 사회과학:
    def 통계학 (self):
        print("통계학")

    def 경제학 (self):
        print("경제학")

    def 정치학 (self):
        print("정치학")

# %%
변수1 = 사회과학()

사회과학.통계학(변수1)
사회과학.경제학(변수1)
사회과학.정치학(변수1)
# Out:
# 통계학
# 경제학
# 정치학

# %% [markdown]
# 함수와 동일하게 메서드의 정의에 따라 메서드를 호출하는 방법이 다릅니다.

# %%
class 수업시간:
    def 예제1(self):
        return "어려워요"

    def 예제2(self, 값):
        print("입력:", 값)

# %%
객체 = 수업시간(  )
y = 수업시간.예제1(객체)
print(y)
수업시간.예제2(객체, 10)
# Out:
# 어려워요
# 입력: 10

# %% [markdown]
# ###### 연습 문제
# 다음의 함수를 "예의바른학생"이라는 이름의 클래스로 정리해 봅시다.

# %%
def 첫인사(이름):
    print("안녕하세요")
    print("반갑습니다")
    print(f"내이름은 {이름}!")
    
def 작별인사():
    print("안녕히가세요")
    print("다음에 뵙겠습니다")

# %%
class 예의바른학생:
    def 첫인사(self, 이름):
        print("안녕하세요")
        print("반갑습니다")
        print(f"내이름은 {이름}!")
        print("--")
        
    def 작별인사(self):
        print("안녕히가세요")
        print("다음에 뵙겠습니다")

# %%
예의바른학생.첫인사(객체, "무지")
예의바른학생.첫인사(객체, "어피치")
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# --
# 안녕하세요
# 반갑습니다
# 내이름은 어피치!
# --

# %% [markdown]
# 예의바른학생에 정의된 `첫인사`, `작별인사` 메서드를 호출하라.

# %%
객체 = 예의바른학생(   )
예의바른학생.첫인사( 객체,  "무지")
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!

# %%
예의바른학생.작별인사( 객체 )
# Out:
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
# 첫 인사와 작별인사 사이에 \n 넣고싶으면 어디에 넣어야하나요?

객체 = 예의바른학생(   )
예의바른학생.첫인사( 객체,  "무지")

예의바른학생.작별인사( 객체 )
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# --
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
# 예의바른학생.첫인사( 객체,  "무지")
객체.첫인사("무지")

# 예의바른학생.작별인사( 객체 )
객체.작별인사( )
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# --
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
class 마린:
    def 공격하기(self):
        print("두두두두두두두")

m = 마린(  )
m.공격하기(  )
# 마린.공격하기(m)
# Out:
# 두두두두두두두

# %% [markdown]
# `클래스1에 있는 f(x)랑 클래스2에 있는 f(x)랑 이름이 똑같아도 클래스1.f(x) 랑 클래스2.f(x)로 구분되어지나요..?`

# %%
class A:
    def run(self):
        print("a")

class B:
    def run(self):
        print("b")

변수1 = A()
변수2 = B()
변수3 = A()

# %%
type(변수1)
# Out:
# __main__.A

# %%
변수2.run()
# Out:
# b

# %% [markdown]
# ## self의 이해

# %% [markdown]
# 메서드에 추가하는 첫 번째 파라미터의 이름입니다. 변수처럼 `self` 대신 다른 이름을 넣어도 정상 동작합니다.

# %%
class 사회과학:
    def 통계학 (ㅇㅇㅇ):
        print("통계학")
        
객체 = 사회과학()
사회과학.통계학(객체)
# Out:
# 통계학

# %% [markdown]
# 하지만 관습적으로 `self`라는 키워드를 사용합니다. 함수의 정의만 보고 클래스 안의 함수인 것을 알아챌 수 있도록 우리도 `self`를 사용하는 것이죠.

# %% [markdown]
# 파이썬은 클래스에 정의된 메서드를 `객체.메서드()` 형태로 쉽게 사용할 수 있는 편의 기능을 제공합니다.

# %%
객체 = 사회과학()
객체.통계학()    # 사회과학.통계학(객체)와 동일한 동작
# Out:
# 통계학

# %% [markdown]
# 객체는 일반적으로 메모리를 가리키는 `변수`와 함께 `.` 그리고 `메서드 이름`을 나열합니다.
# - `객체.메서드명()`

# %% [markdown]
# ###### 연습 문제
# `예의바른학생` 클래스를 메서드 편의 기능을 활용해서 간단히 <span style="color:red">호출</span>하라.

# %%
객체 = 예의바른학생()
# 예의바른학생.첫인사( 객체,  "무지")
객체.첫인사("무지")

# 예의바른학생.작별인사( 객체 )
객체.작별인사( )
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# --
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
객체 = 예의바른학생()
객체.첫인사('무지')

객체.작별인사()
# Out:
# 안녕하세요
# 반갑습니다
# 내이름은 무지!
# --
# 안녕히가세요
# 다음에 뵙겠습니다

# %%
# 질문 : 아까 type에 __main__ 혹시 한번만 더 설명해주실수 있나요?
변수1 = A()
type(변수1)
# Out:
# __main__.A

# %%
__name__
# Out:
# '__main__'

# %%
import numpy as np

a = np.array( [10, 20])
print(type(a))
a.all()
# numpy.ndarray.all(a)
# Out:
# <class 'numpy.ndarray'>
# True

# %%
import pandas as pd

df = pd.DataFrame()
print(type(df))

df.combine()
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 그럼 그 클래스의 메소드가 어떤건지 알고 있으면 맘대로 갖다쓸 수 있는거네요
#
# `네`

# %% [markdown]
# `모듈 = 알집, 클래스 = 폴더, 함수 = 파일, 데이터 = 파일에 적힌 글들 정도로 생각해도 되나요`
#
# 알집이 애매합니다

# %% [markdown]
# ## 인스턴스 변수

# %% [markdown]
# 함수의 지역변수는 함수의 호출 종료와 함께 제거됩니다.

# %%
def 이름입력(name):
    이름 = name
    
def 출력하기():
    print(이름)
    
이름입력("유종훈")
출력하기()

# %% [markdown]
# 인스턴스의 함수 간에는 변수(값)을 공유할 수 있습니다. `self` 변수라고도 불리는데 `self.변수`와 같은 형태로 작성하면 일반 변수와 달리 그 값이 함수의 종료 이후에도 유지됩니다.

# %%
class 사람:
    def 이름입력 (self, 이름):
        self.이름 = 이름

    def 출력하기 (self):
        print(self.이름)

첫째 = 사람()
첫째.이름입력("유종훈")
print(첫째.이름)
첫째.출력하기()
# Out:
# 유종훈
# 유종훈

# %% [markdown]
# 출력하기 메서드 안에서 `self.이름`은 `이름입력` 함수에서 저장한 값입니다. 클래스에서는 `self.이름`과 `이름` 두 가지는 변수명이 비슷하지만 전혀 특성이 다른 변수입니다. 만약 일반 변수 (self가 없는)에 값을 저장했다면 `이름입력` 함수가 종료되면서 제거되기 때문에, 출력하기에서 변수를 사용할 수 없습니다.

# %%
class 사람:
    def 이름입력 (self, 이름):
        너의이름은 = 이름

    def 출력하기 (self):
        print(너의이름은)

첫째 = 사람()
첫째.이름입력("유종훈")
첫째.출력하기()

# %% [markdown]
# 그림과 함께 이해해 봅시다.
# - 사람 객체를 생성하면 메모리 어딘가에 저장되고 첫재라는 이름표를 붙입니다. 첫째 안에는 이름하기(), 출력하기() 메서드가 복사됩니다.
# - `이름입력` 메서드를 호출하면 내부적으로 `self.이름` 변수에 `유종훈`이 저장됩니다. 인스턴스 변수를 사용하면 첫째가 저장된 메모리 공간에  이름을 추가적으로 저장합니다.
# - `출력하기` 메서드를 호출하면 `self.이름`을 가져와서 화면에 출력합니다. 이때 `self`는 메서드가 포함된 객체를 의미하여, `self.이름`은 현재 첫째의 메모리안에 있는 이름이라는 변수를 가리킵니다.

# %% [markdown]
# <img src="https://i.ibb.co/SsjQHdd/class-2.png" width="700" style="float:left" />

# %% [markdown]
# 인스턴스에 저장된 변수는 객체를 사용해서도 가져올 수 있습니다. 첫째 객체 안에 있는 이름이라는 변수에 저장된 값을 가져오니 "유종훈" 이라는 문자열이 출력됩니다.

# %%
class 사람:
    def 이름입력 (self, 이름):
        self.이름 = 이름

    def 출력하기 (self):
        print(self.이름)

첫째 = 사람()
첫째.이름입력("유종훈")

# %%
print(첫째.이름)
# Out:
# 유종훈

# %% [markdown]
# 객체의 외부에서 값을 저장 및 변경할 수 있습니다.

# %%
print(첫째.이름)
첫째.이름 = "철수"
print(첫째.이름)

# %% [markdown]
# 객체는 붕어빵찍듯이 여러 개를 생성할 수있습니다. 코드를 정리해서 재사용성을 높이기 위해서 함수와 클래스를 사용한다고 했었죠? 여기에서 클래스의 장점을 확인할 수 있습니다.

# %%
첫째 = 사람()
첫째.이름입력("유종훈")
print(첫째.이름)

둘째 = 사람()
둘째.이름입력("유정현")
둘째.출력하기()

첫째 = 사람()

# %% [markdown]
# 메모리에서 이를 표현해 봅시다. 첫째와 둘째는 각각 독립적인 공간에 생성이되고 이를 각각의 변수가 가리킵니다. 첫째와 둘째 각각에 `이름입력`, `출력하기` 메서드가 복사됩니다. `이름입력` 메서드를 호출할 때 전달한 파라미터 값이 인스턴스가 저장된 공간에 저장됩니다. 중요한 점은 인턴스 간에는 서로 영향을 받지 않는다는 것입니다.

# %% [markdown]
# <img src="https://i.ibb.co/thvWjLv/class-3.png" width="300" style="float:left" />

# %% [markdown]
# `x=[] 정의 뒤 → 함수를 실행 → 함수 내에서 x.append(10)을 하면 → 함수가 종료된 후에도 x=[10] 이 되는 것이 마찬가지 append가  매서드 라는 건가요?`
#
# `네`

# %% [markdown]
# 처음 클래스 선언할 때와 다르게, 메소드를 실행하면서, 인스턴스 변수가 생성 되었는데, 그러면, 해당 클래스 인스턴스의 메모리 크기도 증가하나요?
#
# `동적으로 크기가 커져요`

# %% [markdown]
# 첫째 = 사람(),  둘째 = 사람() 이거와 class 사람:  상관관계가 있습니까?
#
#
# `설계도(클래스)`를 갖고 만든 결과물이 `객체` 입니다.

# %% [markdown]
# 일반 변수와 인스턴스 변수의 차이
# - 일반 변수는 함수 호출이 끝나면 제거됩니다

# %%
class 사람:
    def 이름입력 (self, 이름):
        너의이름은 = 이름

    def 출력하기 (self):
        print(너의이름은)

첫째 = 사람()
첫째.이름입력("유종훈")
첫째.출력하기()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b99a1eede489> in <module>()
#       8 첫째 = 사람()
#       9 첫째.이름입력("유종훈")
# ---> 10 첫째.출력하기()
#
# <ipython-input-45-b99a1eede489> in 출력하기(self)
#       4
#       5     def 출력하기 (self):
# ----> 6         print(너의이름은)
#       7
#       8 첫째 = 사람()
#
# NameError: name '너의이름은' is not defined

# %%
class 사람:
    def 이름입력 (self, 이름):
        self.너의이름은 = 이름

    def 출력하기 (self):
        print(self.너의이름은)

첫째 = 사람()
# 첫째.이름입력("유종훈")
사람.이름입력(첫째, "유종훈")
첫째.출력하기()
# 여기서 첫째.이름입력() 에 첫째,”유종훈" 이 아니라 "유종훈” 만 넣는 이유는 self 가 자동으로 정의된 객체를 가리켜주기 때문인가요? 변수를 두개 넣어줘야하는 함수로 정의했는데 하나만 넣어줘도 결과 나오는게 이해가 안됩니다 ㅋㅋㅋ
# 파이썬 인터프리터가 위와 같이 변경해 주므로 첫째를 직접 넣어줄 필요없다
# Out:
#   File "<ipython-input-46-52206520a5c0>", line 13
#     첫째,”유종훈"
#           ^
# SyntaxError: invalid character in identifier

# %% [markdown]
# `B 클래스에서 정의된 메소드라도 동일한 모듈안에만 있다면 A클래스에서 생성된 객체에서 B클래스의 메소드를 사용할 수 있을까요??`

# %%
# 네 

class A:
    pass

class B:
    def f( self ):
        a = A(   )

a = B()
a.f()

# %% [markdown]
# 오류의 원인은?
# ```
# class 사람:
#     def 이름입력 (self, 이름):
#         너의이름은 = 이름
#         return 너의이름은
#
#     def 출력하기 (self):
#         print(너의이름은)
#
# 첫째 = 사람()
# 첫째.이름입력("유종훈")
# 첫째.출력하기()
#
# ```

# %%
# 정신차려라. 지역변수다!!!

# %%
class 사람:
    def 이름입력 (self, 이름):
        너의이름은 = 이름
        return 너의이름은

    def 출력하기 (self):
        print(너의이름은)

첫째 = 사람()
결과 = 첫째.이름입력("유종훈")
print(결과)
첫째.출력하기()
# Out:
# 유종훈
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-dec3c2abb3a1> in <module>()
#      10 결과 = 첫째.이름입력("유종훈")
#      11 print(결과)
# ---> 12 첫째.출력하기()
#
# <ipython-input-50-dec3c2abb3a1> in 출력하기(self)
#       5
#       6     def 출력하기 (self):
# ----> 7         print(너의이름은)
#       8
#       9 첫째 = 사람()
#
# NameError: name '너의이름은' is not defined

# %% [markdown]
# 클래스가 할당,확보하는 메모리 동적 자료구조는 링크드리스트인가요?.. 마구 늘어났다가. 다른 것을 쓰고 있는 메모리로까지 침범할 수도 있으니...
#
# `메모리가 꽉 차게되면 프로그램이 사망한다. 에러!!`

# %% [markdown]
# b = []
#
# def aa(x):
#     x = 20
#     b.append(x)
#
#
# x = 10
# aa(x)
# print(b)
# print(x)
#
# 함수 바깥에서 만든 리스트를 함수 안에서 append하는거랑
# 함수 안에서 선언한 변수 결과에 대한 차이점 다시 설명해주실 수 있나요?
#
# `동작상의 차이는 없습니다. 코드를 정리한 사람의 의도대로 실행됩니다. `

# %% [markdown]
# b.f(20) 과 print (z) 값이 다른게 나오는데 이유를 설명해주실수 있을가요?
#
# ```
# z = 10
# class A :
#     def f(self, x) :
#         y = 10
#         z = x+y
#         return z
#         self.z = z
#
# b = A()
# print(b.f(20))
# print("")
# print(z)
# ```
#
# `b.f는 return한 값 30이 출력되며, z 는 위에 정의한 10이 그대로 나옵니다.`
#
# `함수 f의 결괏값을 z에 업데이트하고 싶다면 다음과 같이 코드를 작성합니다`
# ```
# z = b.f(20)
# ```

# %% [markdown]
# `변수 같은 경우는 함수 안에서 새로운 값을 주어도 함수 실행이 끝나면서 초기 상태로 돌아가는데 리스트는 그렇지 않아서 궁금했습니다`

# %%
print(type([]))
# Out:
# <class 'list'>

# %% [markdown]
# ## 초기화자 (Initializer)
# 다음의 사람 클래스를 참고하면 클래스를 생성하는 코드가 반복됩니다.

# %% [markdown]
# ```python
# 엄마 = 사람()
# 엄마.출생("이월순", "640423", "여")
# 엄마.정보출력()
#
# 아빠 = 사람()
# 아빠.출생("유희준", "590125", "남")
# 아빠.정보출력()
# ```

# %%
엄마 = 사람("이월순", "123456", "여")
엄마.정보출력()

# %% [markdown]
# 초기화자를 사용하면 클래스를 생성할 때 값을 함께 입력할 수 있습니다. `__init__`이라는 이름을 갖는 메서드를 초기화자라고 부르는데 이는 특별한 기능을 갖습니다. 초기화자가 정의되면 파이썬 인터프리터는 객체가 생성될 때 자동으로 `__init__` 메서드를 호출해 줍니다. 아래의 코드에서 `__init__` 함수를 호출하지 않았지만 파이썬 인터프리터가 자동으로 호출하여 콘솔창에 "자동호출됨"이라는 문자열이 출력됩니다.

# %%
class 사람 :
    def __init__(self):
        print("자동호출됨")
        
객체 = 사람()
# Out:
# 자동호출됨

# %%
class 사람 :
    def __init__(self, 이름):
        print("자동호출됨", 이름)
        
객체 = 사람(이름="종훈")
# Out:
# 자동호출됨 종훈

# %% [markdown]
# 초기화자에 입력값을 추가하면 객체를 생성할 때 파라미터를 반드시 전달해야 합니다. `__init__` 메서드도 함수의 일종이기 때문에 사용 원리는 함수와 같습니다.

# %%
class 사람 :
    

아빠 = 사람("유희준")
print(아빠.이름)

# %% [markdown]
# 다음과 같이 두 개의 값을 입력받도록 정의하면 두 개의 파라미터를 전달해야 합니다.
# 참고로 pass는 기능을 구현하지 않고 문법 에러를 회피하기 위해 사용하는 키워드입니다.

# %%
class 사람 :
    def __init__(self, 이름, 나이):
        self.이름 = 이름
        self.나이 = 0

객체 = 사람("유희준", 60)

# %%
class 계좌 :
    발급계좌수 = 0    # 클래스 변수

    def __init__(self, 이름, 입금액):
        self.이름 = 이름
        self.입금액 = 입금액
        계좌.발급계좌수 = 계좌.발급계좌수 + 1

a = 계좌("유종훈", 100000)
print(a.이름)
b = 계좌("유정현", 100)
print(b.이름)
# Out:
# 유종훈
# 유정현

# %%
print(계좌.발급계좌수)
# Out:
# 2

# %%
객체1 = 사람()
객체2 = 사람()

# %%
객체1.변수
# Out:
# 10

# %%
객체1.변수 = 30
객체1.변수
# Out:
# 30

# %%
객체2.변수
# Out:
# 10

# %% [markdown]
# 혹시 클래스라고 지금은 보이니까 그런데, 혹시 클래스라고 명시할 수도있나요?

# %%
class 바퀴:
    pass

id(바퀴)
# Out:
# 93871941801120

# %% [markdown]
# `__init__을 여러 입력 조건에 대응하게 할 수 있나요?`
#
# 기본적으로 파이썬은 연산자 오버로딩을 지원하지 않는다.

# %%
class A:
    def __init__(self, a):
        pass

    def __init__(self, a, b):
        pass

A( 10  )
A( 10, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-484275c665be> in <module>()
#       6         pass
#       7
# ----> 8 A( 10  )
#       9 A( 10, 20)
#
# TypeError: __init__() missing 1 required positional argument: 'b'

# %% [markdown]
# 발급 게좌수 변수를 지역변수로 인잇 함수 안에서 생성하고 1씩 추가하는것도 가능한가요??

# %%
class 사람:
    def __init__(self, 숫자):
        self.수 = 숫자

a = 사람(  0  )
b = 사람(  1  )
c = 사람(  2  )

# %%
print(a.수)
print(b.수)
print(c.수)
# Out:
# 0
# 1
# 2

# %%
class 사람:
    def __init__(self):
        self.수 = 0
        self.수 = self.수 + 1

a = 사람()
b = 사람()

# %%
a.수
# Out:
# 1

# %%
b.수
# Out:
# 1

# %%
class 사람:
    수 = 0
    def __init__(self):
        사람.수 = 사람.수 + 1

a = 사람()
b = 사람()

# %%
a.수
# Out:
# 2

# %%
b.수
# Out:
# 2

# %%
a = 사람()
print(a)
# Out:
# <__main__.사람 object at 0x7f32ac19f590>

# %%
class 사람:    
    def __repr__(self):
        return "ㅋㅋㅋ"

객체 = 사람()
print(객체)
# Out:
# ㅋㅋㅋ

# %%
class 계좌 :
    발급계좌수 = 0    # 클래스 변수

    def __init__(self, 이름, 입금액):
        self.이름 = 이름
        self.입금액 = 입금액
        계좌.발급계좌수 = 계좌.발급계좌수 + 1

    def __repr__(self):
        return f"{self.이름} {self.입금액}"

a = 계좌("유종훈", 100000)
b = 계좌("유정현", 100)
print(a)
# Out:
# 유종훈 100000

# %%
a = int(3)
print(type(a))
# Out:
# <class 'int'>

# %%
class MyInt:    
    def bit_length(self):
        return 222

# %%
a.bit_length()
# Out:
# 2

# %%
val = sum(  [10, 20] )

# %%
a = str( "abcs" )
print(a)
# Out:
# abcs

# %%
a = str("abcs")
print(a)
# Out:
# abcs

# %% [markdown]
# `리턴과,, 객체변수.. 가 조금 방식만 다르고 같은 결과를 이끌 수 있는 것 같은데, 리턴을 쓸 때와 객체변수를 쓸 때.. 어떨 때 리턴이 좋고, 어떨때 객체변수가 좋을까요?`
#
# -> `클래스`와 `함수` 어떤게 좋을까요?

# %%
def 엄마():
    return "사랑해요"

# %%
class 우리가족:
    def 엄마(self):
        return "사랑해요"

    def 아빠(self):
        return "좋아해요"

# %%
# 파이썬의 모든 안보이는 부분도 클래스로 이루어져 있다고 이해하면 될까요?
네. 클래스로 이뤄져 있습니다.
# Out:
#   File "<ipython-input-63-5bc22502363e>", line 2
#     네. 클래스로 이뤄져 있습니다.
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# `클래스 변수를 싱글톤 패턴을 구현할 때, 사용할수 있을 것 같은데, 맞나요?`
#
# 네.

# %% [markdown]
# `강사님 강사님이 주신 파일 문제 다 풀었는데 이해가 안되거나 모르는문제가 좀 많은데.... 이럴 경우에는 메일로 보내면 될까요? 슬랙에서 다루긴엔 양이 많아서 ㅠㅠ. 특히 4-9와 5-5에 모르는게 많습니다`
#
# 메일 or 슬랙으로 언제든지 연락주세요

# %% [markdown]
# 클래스간에 똑같은 값을 공유하는 변수를 클래스 변수라고 하고, init 함수에 포함되는 인스턴스 변수는 클래스로 찍어내는 객체마다 다른 변수를 받을 수 있게 하는건가요?
