# %% [markdown]
# ## 선형 대수의 기초
#
# ![image.png](attachment:image.png)
#
#
# - 스칼라(scalar): 단순한 숫자
#
#
# - 벡터(Vector) : 숫자들이 차례대로 list된 것
#
#   ![image-2.png](attachment:image-2.png)
#
#   - 행벡터(row vector): 가로로 길쭉한 벡터
#
#     1 * n
#
#   - 열벡터(column vector):세로로 길쭉한 벡터(Vertical)
#                 n * 1
#
#
# - 집합(set) : 숫자들이 차례대로 list되어있지 않음
#
#
# - 행렬(matrix): 행(row) * 열(column) 꼴인 집합( 두 개의 축을 가지는 숫자들의 집합)
#
# - Matrix Notations
#
# ![image-3.png](attachment:image-3.png)
#
# - 사칙연산
#
# ![image-4.png](attachment:image-4.png)
#
# - 행렬의 곱
#
# ![image-5.png](attachment:image-5.png)
#
#   - 순서가 상관이 있다!!
#
#   ![image-6.png](attachment:image-6.png)
#
#
# - 연산 법칙
#
# ![image-7.png](attachment:image-7.png)
