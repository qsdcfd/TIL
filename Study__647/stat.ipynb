# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, poisson

def norm_cdf_drawer(mu, sigma):
    '''
    x의 범위는 평균을 기준으로 3시그마 전후로 한다
    '''
    fig, ax = plt.subplots(1, 1)
    x = np.linspace(mu-3*sigma,mu+3*sigma, 100)
    ax.plot(x, norm.cdf(x, loc=mu, scale=sigma))

# x의 범위는 0부터 람다의 2배까지
def poisson_cdf_drawer(lamb): 
    poisson_cdf = stats.poisson.cdf(np.arange(0, lamb*2,1),mu=lamb)
    plt.plot(np.arange(0, lamb*2), poisson_cdf, label='Poisson Distribution')
    plt.xlabel('x')
    plt.ylabel('P(X<x)')
    plt.title('Poission({lamb1})'.format(lamb1=lamb))

# %%
norm_cdf_drawer(7, 3)

poisson_cdf_drawer(3)

# %%
poisson_cdf_drawer(10)
