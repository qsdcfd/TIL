# %% [markdown]
# # 기초학습
#
# ### 객체 지향 프로그래밍
#   1) 객체란?
#
#   2) 객체 지향 프로그래밍이란?
#
# ### 클래스 기본 문법
#   1) 클래스 선언 및 인스턴스화
#
#   2) 클래스 속성과 메소드
#
#   3) 생성자
#
#   4) 클래스 변수와 인스턴스 변수
#
# ### 객체 지향 프로그래밍을 하는 이유
# ### 클래스, 조금 더 알아보기 - 상속
# ### n면체 주사위 만들기
#   1) 기획
#
#   2) 주 프로그램 - main 함수
#
#   3) FunnyDice 클래스
#
#  4) FunnyDice 클래스 테스트, get_input 함수
#
#  5) 완성 코드

# %% [markdown]
# ### 객체 지향  프로그래밍
#
# -객체: 속성(상태,변수)과 메소드(동작,함수)를 갖는 것이다,모든 변수에 할당할 수 있고 인자로 넘겨질 수 있는 것들.
#
# -id()함수: 내장함수, 객체의 고유값 반환
#
# -copy()
#  +)얕은 복사: 원본 데이터는 그대로 두고 참조하는 데이터 id만복사
#
# -deepcopy()
#  +)깊은 복사: 원본 객체의 값을 복사한다.
#
# -객체 지향 프로그램
# : 객체를 활용한 프로그래밍으로 자신만의 데이터와 프로시저를 갖고 각 객체들은 서로 연결되어 다른 객체가 제공하는 기능을 사용할 수 있는 유기적인 집합체
#
#  +)추상화(abstraction)
#    : 복잡한 자료, 모듈, 시스템 등으로부터 핵심적인 개념 또는 기능을 간추려 내는 것을 말한다.
#
#   +)캡슐화(encapsulation)
#
#  -객체의 속성(data fields)과 행위(메서드,methods)묶음
#  -실제 구현 내용 일부를 외부에 감추어 은닉
#
#
# ### 클래스 기본 문법
#
# 1.클래스 선언 및 인스턴스화
#
#  -클래스 선언(class 키워드 이용)
#
# ![image.png](attachment:image.png)
#
# class Car:
#     pass
#
# class Car():
#     pass
#
# print(id(Car))
# print(id(Car))
#
#
# print(id(Car()))
# print(id(Car()))
#
#
# print(type(Car))
# print(type(Car()))
#
# 신기한점 id(Car)의 값은 몇 번 호출되더라도 동일하지만
#    id(Car())는 호출될 때마다 id값을 가짐.
#  그 이유는 Car는 type유형의 객체.
#            Car()는 Car타입의 객체 생성
#
#  -객체 인스턴스화
#   : 클래스 객체 만들기->클래스 이용
#   : 선언한 클래스 이름에 괄호 적고 적당한 변수 할당
#
#  +) 객체를 인스턴스화 시키는 거랑 함수에 변수 할당하는 것과 너무나 유사합니다. 허나 표기법의 차이가 있습니다.
#
#    -클래스명 표기법: 카멜 케이스
#      +)클래스 명은 주로 명사로 명명
#
#      +)각 단어의 앞 글자를 대문자로 쓸 것.
#      ex)mycar ->MyCar
#
#    -함수명 표기법: 스네이크 케이스
#     +)함수명은 주로 동사로 명명
#
#     +)단어는 소문자로쓰고 각 단어의 연결은 _ 사용
#
#     ex)mycar -> my_car
#
# mycar = Car()
# mycar2 = Car()
# print(id(mycar))
# print(id(mycar2))
#
# 2.클래스 속성과 메소드
#
#   -클래스 속성
#   :상태 표현, 변수로 나타냄
#
#   :color = 'red', category = 'sports car'
#
#   :인스턴스 객체.속성명 [클래스 속성에 접근하는 법]
#  -메소드
#   :동작 표현, 함수로 나타냄., 키워드 def
#
#   :클래스의 메서드는 첫번째 인자는 self값 적어야함
#
#   :인스턴스객체.메소드명 [메소드를 호출하는 법]
#
#   :매직 메소드
#   https://rszalski.github.io/magicmethods/
#
#   :주행 메서드 : def drive(self) 메서드명 정의.
#
#   :가속 메서드
#     def accel(self,현재 속도 인자명, 가속할 값 인자명)
#
#     현재속도 인자명=current_speed.->self.speed_up
#     인자명= speed_up -> self.current_speed
#
#     * 메소드호출 in 인터프리터(코드 한 줄씩 읽음)
#     인자를 넣지 않아도 인터프리터에는 기본 인자 한개를 사용하고 있고 그것은 self입니다
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
# -접두사 self.
# :인스턴스의 속성으로 사용하고 싶은 변수를 self.써줌
# 왜냐하면, self인자를 통해 선언된 객체 값. 의미한다
#
# -self요약
#
#  1)self는 자기 자신입니다.
#
#  2)클래스에 의해 생성된 객체(인스턴스)를 가리킵니다.
#
#  3)클래스의 메서드는 인자로 해당 인스턴스(self)받음
#
#  4)메소드를 호출할 때는 self인자 전달X
#
#  5)self의 값은 인터프리터가 제공
#
#  6)인스턴스 변수 정의할 때 접두사 self.을 붙여줌
#
#
# 3.생성자
#
#  1)__init__
#
#    -메소드 안에 인자 전달로 객체의 속성값 초기화
#    -지정하고 싶을 때 값을 전달해줌
#
# 4.클래스 변수와 인스턴스 변수
#
#   1)변수명쓰고 값을 할당
#   2)__init__메소드 안에 self.함께 설정
#
#   3)클래스 변수
#   :클래스에 바로 선언된 속성.
#   :모든 객체에서 같은 값을 조회
#   :Manufacture
#
#   4)인스턴스 변수
#   :__init__() 안에 self를 사용해 선언된 변수
#   :객체가 인스턴스화 되면 새로운 값 할당 (공유X)
#   :color, category
#
# 5.상속
# :기존 클래스 기능 유지한 채 새로운 속성만 추가하여
#  새로운 클래스를 선언할 때 사용.
#
# :소괄호 안에 상속받을 클래스 입력을 적음
#
# -자식 클래스,서브 클래스, 파생된 클래스
# : 상속받은 클래스
# : 부모클래스의 변경사항이 그대로 반영됨
#
# -부모 클래스, 슈퍼 클래스, 베이스 클래스
# : 기존 클래스
#
# -상속 사용법
#
#   1)메소드 추가하기(add)
#     :새로운 메소드 추가
#     ex)fly()
#
#   2)메소드 재정의하기(override)
#     :기존 메소드 변경
#     ex)drive()
#
#   3)부모 메소드 호출하기(super())
#
#     ex)
#        def(부모클래스의)메소드이름():
#                super().메소드이름()

# %%
class Car:
    color = 'red'
    category = 'sports car'

    def drive(self):
        print("I'm driving")

    def accel(self, speed_up, current_speed=10):
        self.speed_up = speed_up
        self.current_speed = current_speed + speed_up
        print("speed up", self.speed_up, "driving at", self.current_speed)

# %%
class Car:
    Manufacture = "India"

    def __init__(self, color, category='sedan'):
        self.color = color
        self.category = category

# %%
car1 = Car('red','sports car')
car2 = Car('white')
print(car1.Manufacture, car1.color, car1.category)
print(car2.Manufacture, car2.color, car2.category)
# Out:
# India red sports car
# India white sedan

# %%
class Car:
    Manufacture = "India"

    def __init__(self, color='red', category='sedan'):
        self.color = color
        self.category = category

    def drive(self):
        print("I'm driving")

    def accel(self, speed_up, current_speed=10):
        self.speed_up = speed_up
        self.current_speed = current_speed + self.speed_up
        print("speed up", self.speed_up, "driving at", self.current_speed)

# %%
class NewCar(Car):
    pass

car = NewCar()
car.drive()
car.accel(10)
# Out:
# I'm driving
# speed up 10 driving at 20
