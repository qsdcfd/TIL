# %%
! mkdir -p ~/aiffel/rock_scissor_paper1/scissor1
! mkdir -p ~/aiffel/rock_scissor_paper1/rock1
! mkdir -p ~/aiffel/rock_scissor_paper1/paper1

! ls -l ~/aiffel/rock_scissor_paper1
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Sep 23 10:34 paper1
# drwxr-xr-x 2 root root 4096 Sep 23 10:34 rock1
# drwxr-xr-x 2 root root 4096 Sep 23 10:34 scissor1

# %%
# !unzip ~/aiffel/rock_scissor_paper1/rock1/rock.zip -d ~/aiffel/rock_scissor_paper1/rock1
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper1/rock1/rock.zip.zip
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/0.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/1.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/2.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/3.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/4.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/5.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/6.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/7.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/8.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/9.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/10.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/11.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/12.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/rock1/13.jpg
# ...

# %%
# !unzip ~/aiffel/rock_scissor_paper1/paper1/paper.zip -d ~/aiffel/rock_scissor_paper1/paper1
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper1/paper1/paper.zip.zip
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/0.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/1.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/2.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/3.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/4.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/5.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/6.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/7.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/8.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/9.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/10.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/11.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/12.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/paper1/13.jpg
# ...

# %%
# !unzip ~/aiffel/rock_scissor_paper1/scissor1/scissor.zip -d ~/aiffel/rock_scissor_paper1/scissor1
# Out:
# Archive:  /aiffel/aiffel/rock_scissor_paper1/scissor1/scissor.zip.zip
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/0.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/1.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/2.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/3.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/4.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/5.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/6.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/7.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/8.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/9.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/10.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/11.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/12.jpg
#  extracting: /aiffel/aiffel/rock_scissor_paper1/scissor1/13.jpg
# ...

# %%
from PIL import Image
import os, glob

print("PIL 라이브러리 import 완료!")
# Out:
# PIL 라이브러리 import 완료!

# %%
import os

def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")  
    
	print(len(images), " images to be resized.")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
    
	print(len(images), " images resized.")
	
# 가위 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper1/scissor1"
resize_images(image_dir_path)

print("가위 이미지 resize 완료!")
# Out:
# 1000  images to be resized.
# 1000  images resized.
# 가위 이미지 resize 완료!

# %%
import os

def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")  
    
	print(len(images), " images to be resized.")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
    
	print(len(images), " images resized.")
	
# 바위 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper1/rock1"
resize_images(image_dir_path)

print("바위 이미지 resize 완료!")
# Out:
# 1000  images to be resized.
# 1000  images resized.
# 바위 이미지 resize 완료!

# %%
import os

def resize_images(img_path):
	images=glob.glob(img_path + "/*.jpg")  
    
	print(len(images), " images to be resized.")

    # 파일마다 모두 28x28 사이즈로 바꾸어 저장합니다.
	target_size=(28,28)
	for img in images:
		old_img=Image.open(img)
		new_img=old_img.resize(target_size,Image.ANTIALIAS)
		new_img.save(img, "JPEG")
    
	print(len(images), " images resized.")
	
# 보 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper1/paper1"
resize_images(image_dir_path)

print("보 이미지 resize 완료!")
# Out:
# 1000  images to be resized.
# 1000  images resized.
# 보 이미지 resize 완료!

# %%
import numpy as np

def load_data(img_path, number_of_data=3000):  # 가위바위보 이미지 개수 총합에 주의하세요.
    # 가위 : 0, 바위 : 1, 보 : 2
    img_size=28
    color=3
    #이미지 데이터와 라벨(가위 : 0, 바위 : 1, 보 : 2) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/scissor/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0   # 가위 : 0
        idx=idx+1

    for file in glob.iglob(img_path+'/rock/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   # 바위 : 1
        idx=idx+1  
    
    for file in glob.iglob(img_path+'/paper/*.jpg'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2   # 보 : 2
        idx=idx+1
        
    print("학습데이터(x_train)의 이미지 개수는", idx,"입니다.")
    return imgs, labels

image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper"
(x_train, y_train)=load_data(image_dir_path)
x_train_norm = x_train/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))
# Out:
# 학습데이터(x_train)의 이미지 개수는 300 입니다.
# x_train shape: (3000, 28, 28, 3)
# y_train shape: (3000,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])
print('라벨: ', y_train[0])
# Out:
# 라벨:  0

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

n_channel_1=16
n_channel_2=32
n_dense=64
n_train_epoch=9

model=keras.models.Sequential()
model.add(keras.layers.Conv2D(n_channel_1, (3,3), activation='relu', input_shape=(28,28,3)))
model.add(keras.layers.MaxPool2D(2,2))
model.add(keras.layers.Conv2D(n_channel_2, (3,3), activation='relu'))
model.add(keras.layers.MaxPooling2D((2,2)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(n_dense, activation='relu'))
model.add(keras.layers.Dense(3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 26, 26, 16)        448
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 11, 11, 32)        4640
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                51264
# _________________________________________________________________
# dense_11 (Dense)             (None, 3)                 195
# ...

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

model.fit(x_train_norm, y_train, epochs=n_train_epoch)
# Out:
# Epoch 1/9
# 94/94 [==============================] - 1s 3ms/step - loss: 0.7016 - accuracy: 0.8988
# Epoch 2/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0882 - accuracy: 0.9619
# Epoch 3/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0385 - accuracy: 0.9884
# Epoch 4/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9889
# Epoch 5/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 0.9969
# Epoch 6/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0093 - accuracy: 0.9970
# Epoch 7/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9983
# Epoch 8/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0040 - accuracy: 0.9995
# Epoch 9/9
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000

# %%
! mkdir -p ~/aiffel/rock_scissor_paper1/test1

# %%
image_dir_path = os.getenv("HOME") + "/aiffel/rock_scissor_paper1/test1/testset1"
(x_test, y_test)=load_data(image_dir_path, 3000)
x_test_norm = x_test/255.0

print("x_train shape {}".format(x_test.shape))
print("y_train shape {}".format(y_test.shape))
# Out:
# 학습데이터(x_train)의 이미지 개수는 0 입니다.
# x_train shape (3000, 28, 28, 3)
# y_train shape (3000,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_test[0])
print('라벨:', y_test[0])
# Out:
# 라벨: 0

# %%
test_loss, test_accuracy = model.evaluate(x_test_norm, y_test, verbose=2)
print("test_loss: {}".format(test_loss))
print("test_accuracy: {}".format(test_accuracy))
# Out:
# 94/94 - 0s - loss: 6.1989e-06 - accuracy: 1.0000
# test_loss: 6.198863957251888e-06
# test_accuracy: 1.0
