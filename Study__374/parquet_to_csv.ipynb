# %%
! pip install pyarrow
! pip install fastparquet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.5 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 46.6 MB/s
# ...

# %%
import pandas as pd
import numpy as np

# %%
import pyarrow.parquet as pq

# %%
import pandas as pd
df = pd.read_parquet('/content/articles.parquet',engine="pyarrow")
df.to_csv('projects-0701.csv')

# %%
df
# Out:
#           ID BOARD_URI_NAME WRITER_TYPE  \
# 0          1   Announcement    REALNAME
# 1          5         MeetUp    REALNAME
# 2          8         MeetUp    REALNAME
# 3          9         MeetUp    REALNAME
# 4         10         MeetUp    REALNAME
# ...      ...            ...         ...
# 50186  54497           Test    REALNAME
# 50187  54498      KMDForest       ANONY
# 50188  54499      KMDForest       ANONY
# 50189  54500      KMDForest       ANONY
# 50190  54501           Test    REALNAME
#
#                                                   SHA_ID ANONY_HASH  \
# 0      4e4e709b8bd5a923a0e26bfe221f75dbd9f7efd875d93d...       None
# 1      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...       None
# 2      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...       None
# 3      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...       None
# 4      d63a1f1da4384bf48b4a48502bbf68a860a571fb56c0c1...       None
# ...

# %%
df1 = pd.read_csv("/content/articles.csv")
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (14,15,23,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        Unnamed: 0     ID BOARD_URI_NAME WRITER_TYPE  \
# 0               0      1   Announcement    REALNAME
# 1               1      5         MeetUp    REALNAME
# 2               2      8         MeetUp    REALNAME
# 3               3      9         MeetUp    REALNAME
# 4               4     10         MeetUp    REALNAME
# ...           ...    ...            ...         ...
# 50186       50186  54497           Test    REALNAME
# 50187       50187  54498      KMDForest       ANONY
# 50188       50188  54499      KMDForest       ANONY
# 50189       50189  54500      KMDForest       ANONY
# 50190       50190  54501           Test    REALNAME
#
#                                                   SHA_ID ANONY_HASH  \
# ...

# %%
df1["POPULARITY_SCORE"].hist()
