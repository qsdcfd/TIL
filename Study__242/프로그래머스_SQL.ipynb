# %% [markdown]
# <a href="https://colab.research.google.com/github/qsdcfd/TIL/blob/TIL/Study__242/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%A8%B8%EC%8A%A4_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
SELECT ANIMAL_ID, NAME

FROM ANIMAL_INS

WHERE INTAKE_CONDITION = 'Sick'

# %% [markdown]
# ![image.png](data:image/png;base64,...)
