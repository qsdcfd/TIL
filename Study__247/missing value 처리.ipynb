# %%
import os
import gc
import warnings

import numpy as np
import pandas as pd
import seaborn as sns

# %%
data= pd.read_csv('../Downloads/파이널프로젝트_RAW_210329_210926.csv')
data.head(10)
#105419 rows X 18 columns
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4  970658     478028.0   201797.0  PAYMENT  COMPLETED
# 5  970655     478028.0   201797.0    ORDER  CANCELLED
# 6  970614     477910.0        NaN    ORDER  CANCELLED
# 7  970664     460730.0   200622.0    ORDER  CANCELLED
# 8  970669     478033.0   203178.0  PAYMENT  COMPLETED
# 9  970667     478033.0   203178.0    ORDER  CANCELLED
#
#                                       course_title category_title  format  \
# 0                        올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1                      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 2                             시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  object
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
# ...

# %%
data['coupon_discount_amount'] = data['sale_price'] - data['transaction_amount']#coupon_discount결측치 제거

# %%
data['sale_price'] = df['sale_price'].fillna(data['transaction_amount']) #sale_price 결측치 제거

# %%
data['tax_free_amount'] = df['tax_free_amount'].fillna(data['transaction_amount']) #tax_free_amount 결측치 제거

# %%
data['coupon_discount_amount'] = df['coupon_discount_amount'].fillna(0) #쿠폰 적용 안된 것들 0으로 변환

# %%
for i in range(len(data)):

    data['coupon_title'][i] = data['coupon_discount_amount'][i]
    data['coupon_title'][i] = str(data['coupon_title'][i]).strip('\n') +'원 할인'
# Out:
# /var/folders/80/qwk2_q1s4xj1k0h3b7mtfj000000gn/T/ipykernel_13277/337189032.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['coupon_title'][i] = data['coupon_discount_amount'][i]
# /var/folders/80/qwk2_q1s4xj1k0h3b7mtfj000000gn/T/ipykernel_13277/337189032.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['coupon_title'][i] = str(data['coupon_title'][i]).strip('\n') +'원 할인'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ...

# %%
data['coupon_title'] = data['coupon_title'].fillna(data['coupon_discount_amount']) #쿠폰 제목: 0.0원 할인

# %%
data['pg'] = data['pg'].fillna('default') #NaN은 초기값이므로 default

# %%
data['marketing_start_at'] = data['marketing_start_at'].fillna(data['completed_at']) #날짜 없는 것은 마지막 끝 날짜로

# %%
#method 결측치를 위한 최빈값 구하기
data['method'].agg(**{
    'most_common_value':lambda x:x.mode()
}).reset_index()
# Out:
#              level_0  level_1 method
# 0  most_common_value        0   CARD

# %%
data['method'] = data['method'].fillna('CARD') #최반값 설정

# %%
data['customer_id'] = data['customer_id'].fillna('B2B') # b2b사업:format

# %%
data['category_title'].replace(['데이터 사이언스'], ['데이터사이언스'], inplace= True)

# %%
data.loc[(data.category_title.isnull()) & (data.course_title.str.contains('데이터 사이언티스트')) , 'category_title' ] = '데이터사이언스'
data.loc[(data.category_title.isnull()) & (data.course_title.str.contains('영상편집')) , 'category_title' ] = '영상/3D'

# %%
data.dropna(subset=['category_title'], inplace=True)

# %%
data.loc[(data.course_id.isnull()) & (data.course_title.str.contains('한정판매')) , 'course_id' ] = 0
data.loc[(data.course_id.isnull()) & (data.course_title.str.contains('프로모션')) , 'course_id' ] = 1
data.loc[(data.course_id.isnull()) & (data.course_title.str.contains('묶음')) , 'course_id' ] = 2
data.loc[(data.course_id.isnull()) & (data.course_title.str.contains('초격차')) , 'course_id' ] = 3

# %%
data[80:100]
# Out:
#         id customer_id  course_id     type      state  \
# 80  970877    478135.0   203523.0  PAYMENT  COMPLETED
# 81  970880    453024.0   202301.0  PAYMENT  COMPLETED
# 82  970882    478153.0   204101.0    ORDER  CANCELLED
# 83  970886    478159.0   204325.0  PAYMENT  COMPLETED
# 84  970892    478134.0   203720.0  PAYMENT  COMPLETED
# 85  970891    478134.0   203720.0    ORDER  CANCELLED
# 86  970894    478162.0   203523.0    ORDER  CANCELLED
# 87  970904    478162.0   203523.0  PAYMENT  COMPLETED
# 88  970913    477768.0   203530.0  PAYMENT  COMPLETED
# 89  970908    477768.0   203530.0    ORDER  CANCELLED
# 90  970927    478166.0   203146.0  PAYMENT  COMPLETED
# 91  970909    475306.0   203531.0    ORDER  CANCELLED
# 92  970937    475306.0   203531.0    ORDER  CANCELLED
# 93  970941     69914.0   204265.0    ORDER  CANCELLED
# 94  970947    271544.0        1.0  PAYMENT  COMPLETED
# 95  970938    120463.0   204266.0    ORDER  CANCELLED
# ...

# %%
data.isnull().sum()
# Out:
# id                            0
# customer_id                   0
# course_id                     0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title                  0
# coupon_discount_amount        0
# sale_price                    0
# tax_free_amount               0
# pg                            0
# method                        0
# subcategory_title         19812
# marketing_start_at            0
# dtype: int64

# %%
dataframe = pd.DataFrame(data) ## 데이터프래임 생성
dataframe.to_csv('./Downloads',index=False) ## 구분자를 탭으로 하여 저장. 인덱스칼럼은 저장 안함.

# %%
dataframe.head(5)
# Out:
#        id customer_id  course_id     type      state  \
# 0  970634    504760.0   201435.0    ORDER  CANCELLED
# 1  970650    432862.0   203178.0    ORDER  CANCELLED
# 2  970657     72297.0   204246.0  PAYMENT  COMPLETED
# 3  970656     72297.0   204246.0    ORDER  CANCELLED
# 4  970658    478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format         completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원  2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원  2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인  2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인  2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원  2021-03-28 15:21:54
#
#    transaction_amount coupon_title  coupon_discount_amount  sale_price  \
# 0               90500  20000.0원 할인                 20000.0    110500.0
# ...

# %%
df = pd.read_csv('../Downloads/파이널프로젝트_RAW_210329_210926.csv',header=0, index_col=0)
df = pd.read_csv('./Downloads')
df
# Out:
#              id  customer_id  course_id     type      state  \
# 0        970634     504760.0   201435.0    ORDER  CANCELLED
# 1        970650     432862.0   203178.0    ORDER  CANCELLED
# 2        970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3        970656      72297.0   204246.0    ORDER  CANCELLED
# 4        970658     478028.0   201797.0  PAYMENT  COMPLETED
# ...         ...          ...        ...      ...        ...
# 105397  1364995     640697.0   205365.0  PAYMENT  CANCELLED
# 105398  1364998     670896.0   204159.0  PAYMENT  CANCELLED
# 105399  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105400  1365005     670896.0   204159.0  PAYMENT  CANCELLED
# 105401  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 0             올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원
# 1           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# ...

# %%
df.isnull().sum()
# Out:
# id                            0
# customer_id                   0
# course_id                     0
# type                          0
# state                         0
# course_title                  0
# category_title                0
# format                        0
# completed_at                  0
# transaction_amount            0
# coupon_title                  0
# coupon_discount_amount        0
# sale_price                    0
# tax_free_amount               0
# pg                            0
# method                        0
# subcategory_title         19812
# marketing_start_at            0
# dtype: int64
