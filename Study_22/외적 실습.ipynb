# %%
class Vec3: 
    
    def __init__(self, _x = 0.0, _y = 0.0, _z = 0.00) -> None:
        self.x = _x
        self.y = _y
        self.z = _z
    
    
    
    def __str__(self) -> str:
        return "x: {}, y: {}, z: {}".format(self.x, self.y, self.z)

    def __add__(self, other):
        left = self
        right = other
        return Vec3(left.x + right.x, left.y + right.y, left.z + right.z)

#벡터 길이 구하기
    def lenth(self) :
        #root(a*a + b^2 + c^2)
        result = self.x ** 2 +  self.y ** 2 + self.z **2
        result = result ** 0.5

       

    #단위벡터 
    def dir(self):
        #숙제 벡터의 방향벡터 구현 실수값으로 리턴.
        lenthdir = Vec3.lenth(self)
        result = Vec3(self.x/lenthdir, self.y/lenthdir, self.z/lenthdir)
        return result

   #뺄셈구현
    def __sub__(self, other):
        left = self
        right = other
        return Vec3(left.x - right.x, left.y - right.y, left.z - right.z)
        
        return 
    def dot (self,other):
        
        left = self
        right = other

        result = (left.x * right.x) + (left.y * right.y) + (left.z * right.z)
        
        #같이 구현하기.
        return result
    
    def cross (self,other):
        #결과를 반환할 빈벡터 만들기. 디폴트 연산자로 0,0,0
        #temp(x,y,z)
        
        left = self
        right = other
        
        result = (left.y*right.z - left.z*right.y,
                  left.z*right.x -left.x*right.z,
                  left.x*right.y - left.y*right.x)
        
        return result
    
    def cosdgree(self, other):
        import math
       
        result = math.acos(Vec3.dot(self, other) /
                      (lenthdir*Vec3.lenth(other))
        
        #사잇각은 코사인으로만 구한다.
        #숙제
        return result
