# %% [markdown]
# ### 학습목표
#
# 선형회귀(Linear Regression)에 대해 알아본다.
#
# ### 핵심키워드
#
# 선형회귀(Linear Regression)
#
# 평균 제곱 오차(Mean Squared Error)
#
# 경사하강법(Gradient descent)
#
# ### 주제
#
# Data definition : 학습 데이터(torch.tensor)
#
# Hypothesis : 학습시킬 함수 구현
#
# Compute Loss : loss 계산
#
# Gradient descent : 연속적 모델 개선

# %%
! pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.11.2-cp37-cp37m-manylinux1_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 23.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from torchvision) (1.19.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /opt/conda/lib/python3.7/site-packages (from torchvision) (8.1.0)
# Collecting torch==1.10.1
#   Downloading torch-1.10.1-cp37-cp37m-manylinux1_x86_64.whl (881.9 MB)
#      |████████████████████████████████| 881.9 MB 7.6 kB/s  eta 0:00:01    |▋                               | 16.2 MB 32.0 MB/s eta 0:00:28     |█▌                              | 40.4 MB 32.0 MB/s eta 0:00:27/s eta 0:00:10     |███████████████████████▌        | 647.6 MB 53.1 MB/s eta 0:00:05
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.7/site-packages (from torch==1.10.1->torchvision) (3.7.4.3)
# Installing collected packages: torch, torchvision
# Successfully installed torch-1.10.1 torchvision-0.11.2
# WARNING: You are using pip version 20.3.3; however, version 21.3.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
import numpy as np
import torch

# %%
#Data definition

x_train = torch.FloatTensor([[1], [2], [3]])#입력
y_train = torch.FloatTensor([[2], [4], [6]])#출력

# %% [markdown]
# #### Hypothesis(model)
#
# Liner Regression은 학습 data와 가장 잘 맞는 하나의 직선 찾기
#
# ![image.png](attachment:image.png)

# %%
#Weight와 Bias 0으로 초기화(항상 출력0예측)

W = torch.zeros(1, requires_grad = True) #학습할 것 명시
b = torch.zeros(1, requires_grad = True) #학습할 것 명시


hypothesis = x_train * W + b

# %% [markdown]
# ### Compute Loss(Model 학습)
#
# #### Mean Squared Error(MSE)
#
# 정답과 얼마나 가까운지 확인 작업으로 loss계산
#
# 실제 Training dataset의 y값 차이를 제곱하여 평균
#
#
# ![image.png](attachment:image.png)

# %%
cost = torch.mean((hypothesis - y_train) ** 2)

# %% [markdown]
# ### Gradient descent
#
# - torch.optim 라이브러리 사용
#
#    - [W,b]는 학습할 tensor
#
#    - lr = 0.01
#
# - 항상 붙는 3줄(꼭 기억)
#
#    - zero_grad()로 gradient초기화
#
#    - backward()로 gradient계산
#
#    - step()로 계산 #Gradient방향대로 Weight와 Biase, W와 b 계산합니다.

# %%
optimizer = torch.optim.SGD([W, b], lr=0.01)

optimizer.zero_grad()
cost.backward()
optimizer.step()
